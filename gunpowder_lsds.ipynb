# %%
#@title import packages

import gunpowder as gp
import h5py
import io
import logging
import math
import matplotlib.pyplot as plt
import numpy as np
import random
import requests
import torch
import zarr

from funlib.learn.torch.models import UNet, ConvPass
# from lsd.gp import AddLocalShapeDescriptor
from lsd.train.gp import AddLocalShapeDescriptor
from gunpowder.torch import Train

# %matplotlib inline
logging.basicConfig(level=logging.INFO)
from gunpowder_augmentor import prepare_gunpowder_pipeline

# %%
load_path = '/mnt/efs/shared_data/hack/data/20230811/20230811_raw.zarr'
output_shape = (20, 265, 265)
stack_size = 6
device = 'cpu'

# %%
##### GUNPOWDER PIPELINE #####

def prepare_gunpowder_pipeline(load_path, output_shape=(30, 128, 128), device='cuda'): #stack_size=5
 
    # Define keys
    raw = gp.ArrayKey('RAW')
    gt = gp.ArrayKey('GROUND_TRUTH')
    gt_lsds = gp.ArrayKey('GT_LSDS')
    lsds_weights = gp.ArrayKey('LSDS_WEIGHTS')
    gt_affs = gp.ArrayKey('GT_AFFS')

    # gt_lsds = tf.placeholder(tf.float32, shape=(10,) + output_shape)

    ########  Define paramters ########

    # How many stacks to request
    #stack = gp.Stack(stack_size)

    # random sampeling 
    random_location = gp.RandomLocation()

    # geometric augmentation
    simple_augment = gp.SimpleAugment(
        mirror_probs = [0,0,0],
        transpose_probs = [0,0,0])
    
    elastic_augment = gp.ElasticAugment(
        control_point_spacing=(30, 30, 30),
        jitter_sigma=(1.0, 1.0, 1.0),
        rotation_interval=(0, math.pi/2),
        spatial_dims = 3
    )

    # signal augmentations
    intensity_augment = gp.IntensityAugment(
        raw,
        scale_min=0.9,
        scale_max=1.1,
        shift_min=-0.01,
        shift_max=0.01)

    noise_augment = gp.NoiseAugment(raw, mode='poisson')

    normalize_raw = gp.Normalize(raw)
    


    ##### Gunpowder pipeline #####

    # Load the data
    source = tuple(gp.ZarrSource(
    load_path,
    {
      raw: f'fov{i}/raw',
      gt: f'fov{i}/gt'
    },
    {
      raw: gp.ArraySpec(interpolatable=True,
        voxel_size=(1,1,1)),
      gt: gp.ArraySpec(interpolatable=False,
        voxel_size=(1,1,1)),
    })  + normalize_raw + random_location for i in [1]) 


    # Create the pipeline
    pipeline = source
    pipeline += gp.RandomProvider()
    pipeline += simple_augment
    pipeline += elastic_augment
    # pipeline += stack
    pipeline += intensity_augment
    pipeline += noise_augment

    pipeline += AddLocalShapeDescriptor(
        gt,
        gt_lsds,
        lsds_mask=lsds_weights,
        sigma=80,
        downsample=2)
    
    
    pipeline += gp.AddAffinities(
        affinity_neighborhood=[
        [0, -1],
        [-1, 0]],
        labels=gt, #labels
        affinities=gt_affs,
        dtype=np.float32)
        

    # Define a batch request
    request = gp.BatchRequest()
    request[raw] = gp.Roi((0, 0, 0), output_shape)
    request[gt] = gp.Roi((0, 0, 0), output_shape)
    request[gt_lsds]= gp.Roi((0, 0, 0), output_shape)
    # request.add(gt_lsds, gp.Roi((0, 0, 0), output_shape))

    return pipeline, request
    
pipeline, request = prepare_gunpowder_pipeline(load_path, output_shape, device) #stack_size 


# Build the pipeline and request the batch
with gp.build(pipeline):
    batch = pipeline.request_batch(request)

# Move the batch data to the specified device
if device == 'cuda':
    batch[raw].data = torch.from_numpy(batch[raw].data).cuda()
    batch[gt].data = torch.from_numpy(batch[gt].data).cuda()


print("Raw shape: " + str(batch[gp.ArrayKey('RAW')].data.shape))
print("Ground truth shape: " + str(batch[gp.ArrayKey('GROUND_TRUTH')].data.shape))
# print("Ground truth LSDS shape: " + str(batch[gp.ArrayKey('GT_LSDS')].data.shape))
print("Ground truth affinities shape: " + str(batch[gp.ArrayKey('GT_AFFS')].data.shape))


# # Build the pipeline and request the batch
# with gp.build(pipeline):
#   batch = pipeline.request_batch(request)


# # Move the batch data to the specified device
# if device == 'cuda':
#     batch[raw].data = torch.from_numpy(batch[raw].data).cuda()
#     batch[gt].data = torch.from_numpy(batch[gt].data).cuda()

# Example usage:
#load_path = '/mnt/efs/shared_data/hack/data/20230811/20230811_raw.zarr'
#output_shape = (15, 128, 128)
#stack_size = 7  # Adjust the stack size as needed
#device = 'cuda'  # Change to 'cpu' if you want to use CPU
#result_batch = process_zarr_data(load_path, output_shape, stack_size, device)

#print(result_batch[raw].data.shape)
#print(result_batch[gt].data.shape)

   # Print the shape of the 'raw' data
#print("Raw shape: " + str(result_batch[gp.ArrayKey('RAW')].data.shape))
#print("Ground truth shape: " + str(result_batch[gp.ArrayKey('GROUND_TRUTH')].data.shape))

#########################
# Out:
# ERROR:gunpowder.build:something went wrong during the setup of the pipeline, calling tear down
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/conda/envs/zarr/lib/python3.10/site-packages/gunpowder/pipeline.py:87, in Pipeline.setup.<locals>.node_setup(node)
#      86 try:
# ---> 87     node.output.setup()
#      88 except Exception as e:
#
# File ~/conda/envs/zarr/lib/python3.10/site-packages/gunpowder/nodes/add_affinities.py:170, in AddAffinities.setup(self)
#     168 dims = self.affinity_neighborhood.shape[1]
#     169 self.padding_neg = (
# --> 170     Coordinate(
#     171         min([0] + [a[d] for a in self.affinity_neighborhood])
#     172         for d in range(dims)
#     173     )
#     174     * voxel_size
#     175 )
#     177 self.padding_pos = (
#     178     Coordinate(
#     179         max([0] + [a[d] for a in self.affinity_neighborhood])
#    (...)
#     182     * voxel_size
#     183 )
#
# File ~/conda/envs/zarr/lib/python3.10/site-packages/funlib/geometry/coordinate.py:116, in Coordinate.__mul__(self, other)
#     113 if isinstance(other, Coordinate):
#     115     assert (
# --> 116         self.dims == other.dims
#     117     ), "can only multiply Coordinate of equal dimensions"
#     119     return Coordinate(
#     120         a * b if a is not None and b is not None else None
#     121         for a, b in zip(self, other)
#     122     )
#
# AssertionError: can only multiply Coordinate of equal dimensions
#
# The above exception was the direct cause of the following exception:
#
# PipelineSetupError                        Traceback (most recent call last)
# Cell In[16], line 104
#     100 pipeline, request = prepare_gunpowder_pipeline(load_path, output_shape, device) #stack_size
#     103 # Build the pipeline and request the batch
# --> 104 with gp.build(pipeline):
#     105     batch = pipeline.request_batch(request)
#     107 # Move the batch data to the specified device
#
# File ~/conda/envs/zarr/lib/python3.10/site-packages/gunpowder/build.py:12, in build.__enter__(self)
#      10 def __enter__(self):
#      11     try:
# ---> 12         self.pipeline.setup()
#      13     except:
#      14         logger.error(
#      15             "something went wrong during the setup of the pipeline, calling tear down"
#      16         )
#
# File ~/conda/envs/zarr/lib/python3.10/site-packages/gunpowder/pipeline.py:91, in Pipeline.setup(self)
#      88         except Exception as e:
#      89             raise PipelineSetupError(node.output) from e
# ---> 91     self.traverse(node_setup, reverse=True)
#      92     self.initialized = True
#      93 else:
#
# File ~/conda/envs/zarr/lib/python3.10/site-packages/gunpowder/pipeline.py:59, in Pipeline.traverse(self, callback, reverse)
#      57     result.append(child.traverse(callback, reverse))
#      58 if reverse:
# ---> 59     result.append(callback(self))
#      61 return result
#
# File ~/conda/envs/zarr/lib/python3.10/site-packages/gunpowder/pipeline.py:89, in Pipeline.setup.<locals>.node_setup(node)
#      87     node.output.setup()
#      88 except Exception as e:
# ---> 89     raise PipelineSetupError(node.output) from e
#
# PipelineSetupError: Exception in AddAffinities while calling setup()

# %%
load_path = '/mnt/efs/shared_data/hack/data/20230811/20230811_raw.zarr'
output_shape = (20, 265, 265)
stack_size = 6
device = 'cpu'

pipeline, request = prepare_gunpowder_pipeline(load_path, output_shape, device) #stack_size 

pipeline += AddLocalShapeDescriptor(
    gt,
    gt_lsds,
    lsds_mask=lsds_weights,
    sigma=80,
    downsample=2)
    
# pipeline += gp.AddAffinities(
#     affinity_neighborhood=[
#     [0, -1],
#     [-1, 0]],
#     labels=labels,
#     affinities=gt_affs,
#     dtype=np.float32)



# Build the pipeline and request the batch
with gp.build(pipeline):
    batch = pipeline.request_batch(request)

# Move the batch data to the specified device
if device == 'cuda':
    batch[raw].data = torch.from_numpy(batch[raw].data).cuda()
    batch[gt].data = torch.from_numpy(batch[gt].data).cuda()


print("Raw shape: " + str(batch[gp.ArrayKey('RAW')].data.shape))
print("Ground truth shape: " + str(batch[gp.ArrayKey('GROUND_TRUTH')].data.shape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       4 device = 'cpu'
#       6 pipeline, request = prepare_gunpowder_pipeline(load_path, output_shape, device) #stack_size
#       8 pipeline += AddLocalShapeDescriptor(
# ----> 9     gt,
#      10     gt_lsds,
#      11     lsds_mask=lsds_weights,
#      12     sigma=80,
#      13     downsample=2)
#      15 # pipeline += gp.AddAffinities(
#      16 #     affinity_neighborhood=[
#      17 #     [0, -1],
#    (...)
#      24
#      25 # Build the pipeline and request the batch
#      26 with gp.build(pipeline):
#
# NameError: name 'gt' is not defined

# %%
    pipeline += AddLocalShapeDescriptor(
        labels,
        gt_lsds,
        lsds_mask=lsds_weights,
        sigma=80,
        downsample=2)
        
    pipeline += gp.AddAffinities(
    affinity_neighborhood=[
        [0, -1],
        [-1, 0]],
    labels=labels,
    affinities=gt_affs,
    dtype=np.float32)

# %%
    pipeline += Train(
        model,
        loss,
        optimizer,
        inputs={
            'input': raw
        },
        outputs={
            0: pred_lsds,
            1: pred_affs
        },
        loss_inputs={
            0: pred_lsds,
            1: gt_lsds,
            2: lsds_weights,
            3: pred_affs,
            4: gt_affs,
            5: affs_weights
        })
